# %%
import arcpy,os
import pandas as pd
import json

# %%
def handle_shp_gdb_path(sourcepath) :
    """handles different path formats for shapefiles and geodatabases

    If the path is a shapefie it returns just the path. If the path is a geodatabase it returns also the name of the geo-database.

    Args:
        sourcepath (Path): path relative to the project root

    Returns:
        Path: path of the shapefile or geodatabase
    """
    path = os.path.normpath(sourcepath)
    splitted = path.split(os.sep)

    if splitted[-1].endswith(".shp"):
        # if the path is a shapefile it returns just the path
        return sourcepath
    else:
        # if the path is a geodatabase it returns also the name of the geo-database
        for i,ii in zip(splitted,range(len(splitted))):
            if i.endswith(".gdb"):
                return os.path.join(*splitted[ii:])

# %%
def get_layer_info(imxd):
    """get info about the layers in the mxd file

    Args:
        mxd_path : mxd object

    Returns:
        dict: dictionary with the layer names and the paths to the shapefiles or geodatabases
    """

    lyrs = arcpy.mapping.ListLayers(imxd)

    layers={}
    layers["feature_layers"]={}
    layers["errors"]={}
    layers["broken_layers"]=[]
    layers["basemap_layers"]=[]
    layers["group_layers"]=[]
    for lyr in lyrs:
        if lyr.isBroken:
            layers["broken_layers"].append(lyr.name)
        else:
            # hardcoded to force skip this layers
            if not any(substring in lyr.name for substring in ["World Imagery","Imagery","Metadata","Citations","Default"]):
                if lyr.isFeatureLayer:
                    try:
                        layers["feature_layers"][lyr.name]=handle_shp_gdb_path(lyr.dataSource)
                    except Exception as e:
                        layers["errors"][lyr.name]=(e)
                elif lyr.isBasemapLayer:
                    layers["basemap_layers"].append(lyr.name)
                elif lyr.isGroupLayer:
                    layers["group_layers"].append(lyr.name)
                else:
                    print(lyr.name)
                    print("isFeatureLayer: ",lyr.isFeatureLayer)
                    print("isBasemapLayer: ",lyr.isBasemapLayer)
                    print("isGroupLayer: ",lyr.isGroupLayer)
                    print("isNetworkAnalystLayer: ",lyr.isNetworkAnalystLayer)
                    print("isRasterLayer: ",lyr.isRasterLayer)
                    print("isServiceLayer: ",lyr.isServiceLayer)
                    print("isRasterizingLayer: ",lyr.isRasterizingLayer)
                    print(lyr.supports)
                    raise NotImplementedError("Layer type not implemented")
    return layers

# %%
folderPath = r"C:\Users\GIORGIO.CAIZZI\AECOM\60678625ER Marghera - AdR VP e NP - 09_Temp\00 - GIS\02 - Tavole Modello Concettuale\Nuovo petrolchimico"

tavole={}

for filename in os.listdir(folderPath):
    fullpath = os.path.join(folderPath, filename)
    if os.path.isfile(fullpath):
        basename, extension = os.path.splitext(fullpath)
        if extension.lower() == ".mxd":
            filename=filename.decode("latin8")
            print(filename)
            imxd=arcpy.mapping.MapDocument(fullpath)
            tavole[filename]=get_layer_info(imxd)
            del imxd
# Out:
# A.01 - Planimetria confini proprietà e recettori off-site.mxd
# A.02 - Aree interessate da interventi di ripristino.mxd
# A.03 - Planimetria ubicazione indagini.mxd
# A.09 - Planimetria ubicazione piezometri e concentrazione acque sotterranee.mxd
# A.10 - Ubicazione presenza fonti primarie di contaminazione e MMR.mxd
# A.12.01 - Sorgenti di potenziale contaminazione SS CD Scenario 1.mxd
# A.12.02 - Sorgenti di potenziale contaminazione SS IN Scenario 1.mxd
# A.12.03 - Sorgenti di potenziale contaminazione SP IN Scenario 1.mxd
# A.12.04 - Sorgenti di potenziale contaminazione GW Scenario 1.mxd
# A.12.05 - Sorgenti di potenziale contaminazione SS CD Scenario 2.mxd
# A.12.06 - Sorgenti di potenziale contaminazione SS IN Scenario 2.mxd
# A.12.07 - Sorgenti di potenziale contaminazione SP CD Scenario2.mxd
# A.12.08 - Sorgenti di potenziale contaminazione SP IN Scenario 2.mxd
# A.12.09 - Sorgenti di potenziale contaminazione GW Scenario 2.mxd
# A.13.01 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.02 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.03 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.04 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.05 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.06 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.07 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.08 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.09 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.10 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.11 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.12 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.13 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.14 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.15 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.16 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.17 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.18 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.19 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.20 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.21 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.22 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.23 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.24 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.25 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.13.26 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd
# A.14.1A - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.1B - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.2A - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.2B - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.3A - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.3B - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.4 - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.5 - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.14.6 - Planimetria con ubicazione analisi parametri sito-specifici.mxd
# A.15 - Planimetria ubicazione flux chamber.mxd

# %%
tavole
# Out:
# {u'A.01 - Planimetria confini propriet\xe0 e recettori off-site.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'recettori_rev2': u'NP_ADR_2021.gdb\\recettori_rev2'},
#   'group_layers': []},
#  u'A.02 - Aree interessate da interventi di ripristino.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Aree soggette ad attivit\xe0 di scotico': u'NP_ADR_2021.gdb\\scotico',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Poligoni oggetto di attivit\xe0 di bonifica': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono oggetto di ripristino ambientale (MT-S25-S2)': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'all_polys': u'NP_ADR_2021.gdb\\Aree_MISP',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SP_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2',
#    u'thiessen_SS_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2'},
#   'group_layers': [u'Aree_soggette_a_attivit\xe0_di_scoticoAnno',
#    u'A121_Anno']},
#  u'A.03 - Planimetria ubicazione indagini.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'': u'NP_ADR_2021.gdb\\lotti',
#    u'Sondaggi': u'NP_ADR_2021.gdb\\NP_esiti_rev2'},
#   'group_layers': [u'SONDAGGI']},
#  u'A.09 - Planimetria ubicazione piezometri e concentrazione acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Campione prelevato con concentrazione superiore alla CSC': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'Piezometri intestati nelle acque di impregnazione del riporto': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti'},
#   'group_layers': []},
#  u'A.10 - Ubicazione presenza fonti primarie di contaminazione e MMR.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'01_-_Sondaggi_MMA_NP_rev28032022': u'NP_ADR_2021.gdb\\sondaggi_MMR_rev28032022',
#    u'Lotti_PN': u'NP_ADR_2021.gdb\\lotti',
#    u'Poligono oggetto di ripristino': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Sondaggio con presenza di Amianto': u'NP_ADR_2021.gdb\\NP_esiti_rev2'},
#   'group_layers': [u'mmr_np']},
#  u'A.12.01 - Sorgenti di potenziale contaminazione SS CD Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_1_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_parallel',
#    u'A_12_1_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono oggetto di ripristino ambientale (MT-S25-S2)': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'sorgenti_SS_CD': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_CD_rev2_Buffer': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2_Buffer',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SS_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2'},
#   'group_layers': [u'A_12_1_perpendAnno',
#    u'A121_Anno',
#    u'sorgenti_SS_CDAnno',
#    u'linee_estensione_sorgenti']},
#  u'A.12.02 - Sorgenti di potenziale contaminazione SS IN Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_2_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_parallel',
#    u'A_12_2_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SS_IN': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2',
#    u'sorgenti_SS_IN_Buffer': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2_Buffer',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SS_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2'},
#   'group_layers': [u'A_12_2_parallelAnno',
#    u'A122_Anno',
#    u'sorgenti_SS_INAnno']},
#  u'A.12.03 - Sorgenti di potenziale contaminazione SP IN Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_3_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_parallel',
#    u'A_12_3_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SP_IN': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SP_IN_Buffer': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5_Buffer',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SP_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2'},
#   'group_layers': [u'A_12_3_perpendAnno',
#    u'A123_Anno',
#    u'sorgenti_SP_INAnno']},
#  u'A.12.04 - Sorgenti di potenziale contaminazione GW Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_4_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_parallel',
#    u'A_12_4_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici': u'NP_ADR_2021.gdb\\edifici',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'Piezometri riporto': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'Poligoni di Thiessen': u'NP_ADR_2021.gdb\\Thiessen_GW_3_clipped',
#    u'Sorgenti secondarie di contaminazione acque sotterranee': u'NP_ADR_2021.gdb\\lotti',
#    u'edifici_Buffer1': u'NP_ADR_2021.gdb\\edifici_Buffer1'},
#   'group_layers': [u'LottiAnno']},
#  u'A.12.05 - Sorgenti di potenziale contaminazione SS CD Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_1_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_parallel',
#    u'A_12_1_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono oggetto di ripristino ambientale (MT-S25-S2)': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'sorgenti_SS_CD': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SS_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2'},
#   'group_layers': [u'sorgenti_SS_CDAnno',
#    u'A121_Anno',
#    u'linee_estensione_sorgenti']},
#  u'A.12.06 - Sorgenti di potenziale contaminazione SS IN Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_2_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_parallel',
#    u'A_12_2_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SS_IN': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SS_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2'},
#   'group_layers': [u'A_12_2_perpendAnno',
#    u'sorgenti_SS_INAnno',
#    u'A122_Anno']},
#  u'A.12.07 - Sorgenti di potenziale contaminazione SP CD Scenario2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_7_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_7_parallel',
#    u'A_12_7_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_7_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono sottoposto a ripristino ambientale (MT-S35-S2)': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'sorgenti_SP_CD': u'NP_ADR_2021.gdb\\sorgenti_SP_CD_rev3',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SP_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2'},
#   'group_layers': [u'A_12_7_perpendAnno',
#    u'A127_Anno',
#    u'sorgenti_SP_CDAnno']},
#  u'A.12.08 - Sorgenti di potenziale contaminazione SP IN Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_3_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_parallel',
#    u'A_12_3_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SP_IN': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SP_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2'},
#   'group_layers': [u'sorgenti_SP_INAnno', u'A123_Anno']},
#  u'A.12.09 - Sorgenti di potenziale contaminazione GW Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_4_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_parallel',
#    u'A_12_4_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'Piezometri riporto': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'Sorgenti secondarie di contaminazione acque sotterranee': u'NP_ADR_2021.gdb\\lotti',
#    u'Thiessen_GW_3_clipped': u'NP_ADR_2021.gdb\\Thiessen_GW_3_clipped'},
#   'group_layers': [u'LottiAnno']},
#  u'A.13.01 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.02 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.03 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.04 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.05 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.06 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.07 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.08 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.09 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.10 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.11 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.12 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.13 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.14 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.15 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.16 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.17 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.18 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.19 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.20 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.21 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.22 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.23 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.24 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.25 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.26 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.14.1A - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Top soil - Suolo superficiale': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Top_soil___Suolo_superficialeAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.1B - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Suolo superficiale - Suolo profondo': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Suolo_superficiale___Suolo_profondoAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.2A - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Top soil - Suolo superficiale': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Top_soil___Suolo_superficialeAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.2B - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Suolo superficiale - suolo profondo': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Suolo_superficiale___Suolo_profondoAnno',
#    u'Top_soil___Suolo_superficialeAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.3A - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Top soil - suolo superficiale': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'sorgenti_SS_CDAnno', u'sorgenti_SP_INAnno']},
#  u'A.14.3B - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Suolo superficiale - Suolo profondo': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'sorgenti_SS_CDAnno', u'sorgenti_SP_INAnno']},
#  u'A.14.4 - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Campione prelevato': u'NP_ADR_2021.gdb\\analisi_sito_specifiche_HG',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Campione_prelevatoAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.5 - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'MMR': u'NP_ADR_2021.gdb\\sondaggi_MMR_rev28032022',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': []},
#  u'A.14.6 - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'MMR': u'NP_ADR_2021.gdb\\sondaggi_MMR_rev28032022',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': []},
#  u'A.15 - Planimetria ubicazione flux chamber.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2',
#    u'ubicazione_fluxchamber': u'NP_ADR_2021.gdb\\ubicazione_fluxchamber'},
#   'group_layers': [u'ubicazione_fluxchamberAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']}}

# %%
# Encode the strings to UTF-8
encoded_tavole = {k: str(v).decode("utf-8") if isinstance(v, str) else v for k, v in tavole.iteritems()}

# %%
encoded_tavole
# Out:
# {u'A.01 - Planimetria confini propriet\xe0 e recettori off-site.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'recettori_rev2': u'NP_ADR_2021.gdb\\recettori_rev2'},
#   'group_layers': []},
#  u'A.02 - Aree interessate da interventi di ripristino.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Aree soggette ad attivit\xe0 di scotico': u'NP_ADR_2021.gdb\\scotico',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Poligoni oggetto di attivit\xe0 di bonifica': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono oggetto di ripristino ambientale (MT-S25-S2)': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'all_polys': u'NP_ADR_2021.gdb\\Aree_MISP',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SP_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2',
#    u'thiessen_SS_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2'},
#   'group_layers': [u'Aree_soggette_a_attivit\xe0_di_scoticoAnno',
#    u'A121_Anno']},
#  u'A.03 - Planimetria ubicazione indagini.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'': u'NP_ADR_2021.gdb\\lotti',
#    u'Sondaggi': u'NP_ADR_2021.gdb\\NP_esiti_rev2'},
#   'group_layers': [u'SONDAGGI']},
#  u'A.09 - Planimetria ubicazione piezometri e concentrazione acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Campione prelevato con concentrazione superiore alla CSC': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'Piezometri intestati nelle acque di impregnazione del riporto': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti'},
#   'group_layers': []},
#  u'A.10 - Ubicazione presenza fonti primarie di contaminazione e MMR.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'01_-_Sondaggi_MMA_NP_rev28032022': u'NP_ADR_2021.gdb\\sondaggi_MMR_rev28032022',
#    u'Lotti_PN': u'NP_ADR_2021.gdb\\lotti',
#    u'Poligono oggetto di ripristino': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Sondaggio con presenza di Amianto': u'NP_ADR_2021.gdb\\NP_esiti_rev2'},
#   'group_layers': [u'mmr_np']},
#  u'A.12.01 - Sorgenti di potenziale contaminazione SS CD Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_1_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_parallel',
#    u'A_12_1_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono oggetto di ripristino ambientale (MT-S25-S2)': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'sorgenti_SS_CD': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_CD_rev2_Buffer': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2_Buffer',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SS_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2'},
#   'group_layers': [u'A_12_1_perpendAnno',
#    u'A121_Anno',
#    u'sorgenti_SS_CDAnno',
#    u'linee_estensione_sorgenti']},
#  u'A.12.02 - Sorgenti di potenziale contaminazione SS IN Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_2_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_parallel',
#    u'A_12_2_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SS_IN': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2',
#    u'sorgenti_SS_IN_Buffer': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2_Buffer',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SS_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2'},
#   'group_layers': [u'A_12_2_parallelAnno',
#    u'A122_Anno',
#    u'sorgenti_SS_INAnno']},
#  u'A.12.03 - Sorgenti di potenziale contaminazione SP IN Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_3_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_parallel',
#    u'A_12_3_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SP_IN': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SP_IN_Buffer': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5_Buffer',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SP_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2'},
#   'group_layers': [u'A_12_3_perpendAnno',
#    u'A123_Anno',
#    u'sorgenti_SP_INAnno']},
#  u'A.12.04 - Sorgenti di potenziale contaminazione GW Scenario 1.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_4_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_parallel',
#    u'A_12_4_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici': u'NP_ADR_2021.gdb\\edifici',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'Piezometri riporto': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'Poligoni di Thiessen': u'NP_ADR_2021.gdb\\Thiessen_GW_3_clipped',
#    u'Sorgenti secondarie di contaminazione acque sotterranee': u'NP_ADR_2021.gdb\\lotti',
#    u'edifici_Buffer1': u'NP_ADR_2021.gdb\\edifici_Buffer1'},
#   'group_layers': [u'LottiAnno']},
#  u'A.12.05 - Sorgenti di potenziale contaminazione SS CD Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_1_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_parallel',
#    u'A_12_1_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_1_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono oggetto di ripristino ambientale (MT-S25-S2)': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'sorgenti_SS_CD': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SS_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_CD_rev2'},
#   'group_layers': [u'sorgenti_SS_CDAnno',
#    u'A121_Anno',
#    u'linee_estensione_sorgenti']},
#  u'A.12.06 - Sorgenti di potenziale contaminazione SS IN Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_2_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_parallel',
#    u'A_12_2_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_2_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SS_IN': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SS_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SS_IN_rev2'},
#   'group_layers': [u'A_12_2_perpendAnno',
#    u'sorgenti_SS_INAnno',
#    u'A122_Anno']},
#  u'A.12.07 - Sorgenti di potenziale contaminazione SP CD Scenario2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_7_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_7_parallel',
#    u'A_12_7_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_7_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'Poligono sottoposto a ripristino ambientale (MT-S35-S2)': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'sorgenti_SP_CD': u'NP_ADR_2021.gdb\\sorgenti_SP_CD_rev3',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_rev2',
#    u'thiessen_SP_CD_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_CD_rev2'},
#   'group_layers': [u'A_12_7_perpendAnno',
#    u'A127_Anno',
#    u'sorgenti_SP_CDAnno']},
#  u'A.12.08 - Sorgenti di potenziale contaminazione SP IN Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_3_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_parallel',
#    u'A_12_3_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_3_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'MMR': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'Poligoni di thiessen': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2',
#    u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'labels': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'sorgenti_SP_IN': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'terreno': u'NP_ADR_2021.gdb\\NP_esiti_inal_rev2',
#    u'thiessen_SP_IN_rev2': u'NP_ADR_2021.gdb\\thiessen_SP_IN_rev2'},
#   'group_layers': [u'sorgenti_SP_INAnno', u'A123_Anno']},
#  u'A.12.09 - Sorgenti di potenziale contaminazione GW Scenario 2.mxd': {'basemap_layers': [],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'A_12_4_parallel': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_parallel',
#    u'A_12_4_perpend': u'NP_ADR_2021.gdb\\linee_estensione_sorgenti\\A_12_4_perpend',
#    u'Carta Tecnica Regionale': u'NP_ADR_2021.gdb\\ctr',
#    u'Edifici considerati': u'NP_ADR_2021.gdb\\edifici',
#    u'Lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'Piezometri riporto': u'NP_ADR_2021.gdb\\piezometri_riporto',
#    u'Sorgenti secondarie di contaminazione acque sotterranee': u'NP_ADR_2021.gdb\\lotti',
#    u'Thiessen_GW_3_clipped': u'NP_ADR_2021.gdb\\Thiessen_GW_3_clipped'},
#   'group_layers': [u'LottiAnno']},
#  u'A.13.01 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.02 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.03 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.04 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.05 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.06 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.07 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.08 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.09 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.10 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.11 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.12 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.13 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.14 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.15 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.16 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.17 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.18 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.19 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.20 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.21 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.22 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.23 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.24 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.25 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.13.26 - Planimetria ubicazione eccedenze delle CSC per i contaminanti nelle acque sotterranee.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'piezometri_riporto': u'NP_ADR_2021.gdb\\piezometri_riporto'},
#   'group_layers': []},
#  u'A.14.1A - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Top soil - Suolo superficiale': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Top_soil___Suolo_superficialeAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.1B - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Suolo superficiale - Suolo profondo': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Suolo_superficiale___Suolo_profondoAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.2A - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Top soil - Suolo superficiale': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Top_soil___Suolo_superficialeAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.2B - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Suolo superficiale - suolo profondo': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Suolo_superficiale___Suolo_profondoAnno',
#    u'Top_soil___Suolo_superficialeAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.3A - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Top soil - suolo superficiale': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'sorgenti_SS_CDAnno', u'sorgenti_SP_INAnno']},
#  u'A.14.3B - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Suolo superficiale - Suolo profondo': u'NP_ADR_2021.gdb\\analisi_sito_specifiche',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'sorgenti_SS_CDAnno', u'sorgenti_SP_INAnno']},
#  u'A.14.4 - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Campione prelevato': u'NP_ADR_2021.gdb\\analisi_sito_specifiche_HG',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': [u'Campione_prelevatoAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']},
#  u'A.14.5 - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'MMR': u'NP_ADR_2021.gdb\\sondaggi_MMR_rev28032022',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': []},
#  u'A.14.6 - Planimetria con ubicazione analisi parametri sito-specifici.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'MMR': u'NP_ADR_2021.gdb\\sondaggi_MMR_rev28032022',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2'},
#   'group_layers': []},
#  u'A.15 - Planimetria ubicazione flux chamber.mxd': {'basemap_layers': [u'Basemap'],
#   'broken_layers': [],
#   'errors': {},
#   'feature_layers': {u'Poligoni oggetto di MISP': u'NP_ADR_2021.gdb\\misp',
#    u'lotti': u'NP_ADR_2021.gdb\\lotti',
#    u'sorgenti_SP_IN_rev5': u'NP_ADR_2021.gdb\\sorgenti_SP_IN_rev5',
#    u'sorgenti_SS_CD_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_CD_rev2',
#    u'sorgenti_SS_IN_rev2': u'NP_ADR_2021.gdb\\sorgenti_SS_IN_rev2',
#    u'ubicazione_fluxchamber': u'NP_ADR_2021.gdb\\ubicazione_fluxchamber'},
#   'group_layers': [u'ubicazione_fluxchamberAnno',
#    u'sorgenti_SS_CDAnno',
#    u'sorgenti_SP_INAnno']}}

# %%
with open('tavole.json', 'w+') as fp:
    json.dump(encoded_tavole, fp, indent=4)
