# %%
import os
from pathlib import Path
import pandas as pd

# %%
path = Path(r'C:\Users\GIORGIO.CAIZZI\AECOM\60678625ER Marghera - AdR VP e NP - 09_Temp\00 - GIS\02 - Tavole Modello Concettuale\Nuovo petrolchimico')
mxd_list = list(path.glob('*.mxd'))
mxd_list = [os.path.basename(mxd) for mxd in mxd_list]

df = pd.DataFrame(mxd_list, columns=['mxd'])

df
# Out:
#                                                   mxd
# 0   A.01 - Planimetria confini proprietà e recetto...
# 1          A.03 - Planimetria ubicazione indagini.mxd
# 2   A.09 - Planimetria ubicazione piezometri e con...
# 3   A.10 - Ubicazione presenza fonti primarie di c...
# 4   A.12.01 - Sorgenti di potenziale contaminazion...
# 5   A.12.02 - Sorgenti di potenziale contaminazion...
# 6   A.12.03 - Sorgenti di potenziale contaminazion...
# 7   A.12.04 - Sorgenti di potenziale contaminazion...
# 8   A.12.05 - Sorgenti di potenziale contaminazion...
# 9   A.12.06 - Sorgenti di potenziale contaminazion...
# 10  A.12.07 - Sorgenti di potenziale contaminazion...
# 11  A.12.08 - Sorgenti di potenziale contaminazion...
# 12  A.12.09 - Sorgenti di potenziale contaminazion...
# 13  A.13.01 - Planimetria ubicazione eccedenze del...
# 14  A.13.02 - Planimetria ubicazione eccedenze del...
# 15  A.13.03 - Planimetria ubicazione eccedenze del...
# ...

# %%
df.to_excel('lista_tavole.xlsx', index=False)
